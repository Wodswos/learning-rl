# %%
from collections import namedtuple
import random

# %%
# s_t, a_t => s_{t+1}
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
class ReplayMemory:
    
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.index = 0
        
    def push(self, state, action, next_state, reward):
        if len(self.memory) < self.capacity:
            # placeholder
            self.memory.append(None)
        self.memory[self.index] = Transition(state, action, next_state, reward)
        self.index = (self.index + 1) % self.capacity
        
    # list of transition
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    def __len__(self):
        return len(self.memory)

# %%
from torch import nn
import torch
import torch.nn.functional as F
from torch import optim

# %%
# Q_function base NN
class DQN(nn.Module):
    def __init__(self, n_states, n_actions):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(n_states, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, n_actions)
    def forward(self, x):
        # x.shape: batch_size*n_states
        # output.shape: batch_size*n_actions, state_action_value
        return self.fc3(F.relu(self.fc2(F.relu(self.fc1(x)))))

# %%
trs = [Transition(1, 2, 3, 4), Transition(5, 6, 7, 8)]
trs = Transition(*zip(*trs))
trs
# Out:
# Transition(state=(1, 5), action=(2, 6), next_state=(3, 7), reward=(4, 8))

# %%
t = torch.rand(3, 2)
print(t)
print(t.max(dim=1)[0])
t.max(dim=1)[1]
# Out:
# tensor([[0.3459, 0.6515],
#         [0.6835, 0.4760],
#         [0.1795, 0.2964]])
# tensor([0.6515, 0.6835, 0.2964])
# tensor([1, 0, 1])

# %%
class Agent:
    def __init__(self, n_states, n_actions, eta=0.5, gamma=0.99, capacity=10000, batch_size=32):
        self.n_states = n_states
        self.n_actions = n_actions
        self.eta = eta
        self.gamma = gamma
        self.batch_size = batch_size
        
        self.memory = ReplayMemory(capacity)
        self.model = DQN(n_states, n_actions)
        
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.0001)
    
    def _replay(self):
        if len(self.memory) < self.batch_size:
            return
        # list of transition
        batch = self.memory.sample(self.batch_size)
        # Transition, column: len(tuple) == batch_size
        batch = Transition(*zip(*batch))
        
        # s_t.shape: batch_size * 4
        state_batch = torch.cat(batch.state)
        # a_t.shape: batch_size * 1
        action_batch = torch.cat(batch.action)
        # r_{t+1}.shape: batch_size * 1
        reward_batch = torch.cat(batch.reward)
        # < batch_size
        non_final_next_state_batch = torch.cat([s for s in batch.next_state if s is not None])
        
    
        # 构造模型训练用的输入和输出（true）
        # s_t, input
        
        # pred: Q(s_t, a_t)
        # true: R_{t+1} + \gamma*\max_aQ(s_t, a)
        
        # 开启 eval 模式
        self.model.eval()
        
        # pred, batch_size*1
        state_action_values = self.model(state_batch).gather(dim=1, index=action_batch)
        
        # true: R_{t+1} + \gamma*\max_aQ(s_t, a)
        # tuple(map(lambda s: s is not None, batch.next_state)): batch_size 长度的 0/1
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, batch.next_state)))
        next_state_values = torch.zeros(self.batch_size)
        # Q(s_{t+1}, a)
        next_state_values[non_final_mask] = self.model(non_final_next_state_batch).max(dim=1)[0].detach()
        
        # (batch_size, )
        expected_state_action_values = reward_batch + self.gamma * next_state_values
        
        
        # 开启train mode
        self.model.train()
        
        # expected_state_action_values.unsqueeze(1): (batch_size, ) => (batch_size, 1)
        loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
    
    def update_q_function(self):
        self._replay()
        
    def memorize(self, state, action, next_state, reward):
        self.memory.push(state, action, next_state, reward)
    
    # action policy
    # epsilon_greedy
    # double e: explore, exploit
    def choose_action(self, state, episode):
        eps = 0.5*1/(1+episode)
        if random.random() < eps:
            # explore
            action = torch.IntTensor([[random.randrange(self.n_actions)]])
        else:
            self.model.eval()
            with torch.no_grad():
                action = self.model(state).max(1)[1].view(1, 1)
        return action

# %%
import gymnasium as gym

env = gym.make('CartPole-v1')

print(env.observation_space.shape[0])
print(env.action_space.n)
# Out:
# 4
# 2

# %%
env.reset()
# Out:
# (array([-0.00781699,  0.03912979,  0.00963907, -0.01852011], dtype=float32),
#  {})

# %%
from JSAnimation.IPython_display import display_animation
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from matplotlib import animation

# %%
def display_frames_as_gif(frames, output):
    """
    Displays a list of frames as a gif, with controls
    以gif格式显示关键帧列，带有控件
    """
    
    fig = plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        img = patch.set_data(frames[i])
        return img   ## *** return是必须要有的 ***
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    
    anim.save(output)
    return HTML(anim.to_jshtml())  ## *** 返回一个HTML对象，以便被调用者显示。 ***
    # display(display_animation(anim, default_mode='loop'))

# %%
env = gym.make('CartPole-v1')
n_states = env.observation_space.shape[0]
n_actions = env.action_space.n

max_episodes = 500
max_steps = 200

complete_episodes = 0
finished_flag = False

agent = Agent(n_states, n_actions)
frames = []

for episode in range(max_episodes):
    state = env.reset()[0]
    state = torch.from_numpy(state).type(torch.FloatTensor).unsqueeze(0)
    for step in range(max_steps):
        if finished_flag == True:
            frames.append(env.render(mode='rgb_array'))
        # IntTensor of 1*1
        action = agent.choose_action(state, episode)[0][0].numpy()
        # action = random.randrange(2)
        # print(f'state: {state}, action: {action}')
        # transition on env
        # cartpole v0: next_state, _, done, _ = env.step(action.item())
        next_state, reward, terminated, truncated, info = env.step(action)
        
        if terminated:
            next_state = None
            
            if step < 195:
                # 1d
                reward = torch.FloatTensor([-1.])
                complete_episodes = 0
            else:
                reward =  torch.FloatTensor([1.])
                complete_episodes += 1
        else:
            reward = torch.FloatTensor([0])
            # (4, )
            next_state = torch.from_numpy(next_state).type(torch.FloatTensor)
            # (4, ) ==> (1, 4)，便于后续的 torch.cat => (1, 4) => (32, 4)
            next_state = next_state.unsqueeze(0)
            
        # 和示例相比多了一些类型转换。
        agent.memorize(state, torch.tensor([[int(action)]], dtype=torch.int64), next_state, reward)
        agent.update_q_function()
        state = next_state
        
        if terminated:
            print(f'episode: {episode}, steps: {step}')
            break
        
    if finished_flag == True:
        break
        
    if complete_episodes >= 10:
        finished_flag = True
        print('连续成功10轮')
# Out:
# episode: 0, steps: 18
# episode: 1, steps: 27
# episode: 2, steps: 15
# episode: 3, steps: 13
# episode: 4, steps: 17
# episode: 5, steps: 40
# episode: 6, steps: 18
# /tmp/ipykernel_678968/153055639.py:49: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ../aten/src/ATen/native/IndexingUtils.h:27.)
#   next_state_values[non_final_mask] = self.model(non_final_next_state_batch).max(dim=1)[0].detach()
# episode: 7, steps: 54
# episode: 8, steps: 12
# episode: 9, steps: 31
# episode: 10, steps: 14
# episode: 11, steps: 15
# episode: 12, steps: 26
# episode: 13, steps: 15
# episode: 14, steps: 29
# episode: 15, steps: 28
# episode: 16, steps: 26
# episode: 17, steps: 11
# episode: 18, steps: 12
# episode: 19, steps: 12
# episode: 20, steps: 41
# episode: 21, steps: 25
# episode: 22, steps: 42
# episode: 23, steps: 35
# episode: 24, steps: 19
# episode: 25, steps: 59
# episode: 26, steps: 12
# episode: 27, steps: 20
# episode: 28, steps: 9
# episode: 29, steps: 42
# episode: 30, steps: 18
# episode: 31, steps: 16
# episode: 32, steps: 12
# episode: 33, steps: 14
# episode: 34, steps: 35
# episode: 35, steps: 28
# episode: 36, steps: 33
# episode: 37, steps: 14
# episode: 38, steps: 36
# episode: 39, steps: 14
# episode: 40, steps: 16
# episode: 41, steps: 20
# episode: 42, steps: 23
# episode: 43, steps: 15
# episode: 44, steps: 19
# episode: 45, steps: 19
# episode: 46, steps: 32
# episode: 47, steps: 10
# episode: 48, steps: 17
# episode: 49, steps: 12
# episode: 50, steps: 15
# episode: 51, steps: 20
# episode: 52, steps: 13
# episode: 53, steps: 46
# episode: 54, steps: 31
# episode: 55, steps: 17
# episode: 56, steps: 32
# episode: 57, steps: 16
# episode: 58, steps: 55
# episode: 59, steps: 21
# episode: 60, steps: 16
# episode: 61, steps: 25
# episode: 62, steps: 13
# episode: 63, steps: 41
# episode: 64, steps: 34
# episode: 65, steps: 11
# episode: 66, steps: 35
# episode: 67, steps: 29
# episode: 68, steps: 30
# episode: 69, steps: 22
# episode: 70, steps: 14
# episode: 71, steps: 24
# episode: 72, steps: 11
# episode: 73, steps: 13
# episode: 74, steps: 37
# episode: 75, steps: 15
# episode: 76, steps: 12
# episode: 77, steps: 40
# episode: 78, steps: 18
# episode: 79, steps: 19
# episode: 80, steps: 41
# episode: 81, steps: 13
# episode: 82, steps: 12
# episode: 83, steps: 20
# episode: 84, steps: 17
# episode: 85, steps: 30
# episode: 86, steps: 11
# episode: 87, steps: 16
# episode: 88, steps: 20
# episode: 89, steps: 19
# episode: 90, steps: 14
# episode: 91, steps: 20
# episode: 92, steps: 18
# episode: 93, steps: 23
# episode: 94, steps: 11
# episode: 95, steps: 22
# episode: 96, steps: 11
# episode: 97, steps: 14
# episode: 98, steps: 12
# episode: 99, steps: 21
# episode: 100, steps: 16
# episode: 101, steps: 39
# episode: 102, steps: 31
# episode: 103, steps: 16
# episode: 104, steps: 35
# episode: 105, steps: 11
# episode: 106, steps: 24
# episode: 107, steps: 46
# episode: 108, steps: 11
# episode: 109, steps: 21
# episode: 110, steps: 10
# episode: 111, steps: 37
# episode: 112, steps: 17
# episode: 113, steps: 19
# episode: 114, steps: 17
# episode: 115, steps: 12
# episode: 116, steps: 14
# episode: 117, steps: 35
# episode: 118, steps: 22
# episode: 119, steps: 19
# episode: 120, steps: 20
# episode: 121, steps: 54
# episode: 122, steps: 25
# episode: 123, steps: 19
# episode: 124, steps: 42
# episode: 125, steps: 19
# episode: 126, steps: 18
# episode: 127, steps: 12
# episode: 128, steps: 13
# episode: 129, steps: 24
# episode: 130, steps: 12
# episode: 131, steps: 31
# episode: 132, steps: 15
# episode: 133, steps: 13
# episode: 134, steps: 15
# episode: 135, steps: 15
# episode: 136, steps: 38
# episode: 137, steps: 8
# episode: 138, steps: 12
# episode: 139, steps: 46
# episode: 140, steps: 38
# episode: 141, steps: 9
# episode: 142, steps: 9
# episode: 143, steps: 24
# episode: 144, steps: 37
# episode: 145, steps: 21
# episode: 146, steps: 26
# episode: 147, steps: 13
# episode: 148, steps: 11
# episode: 149, steps: 8
# episode: 150, steps: 8
# episode: 151, steps: 9
# episode: 152, steps: 49
# episode: 153, steps: 19
# episode: 154, steps: 21
# episode: 155, steps: 13
# episode: 156, steps: 12
# episode: 157, steps: 20
# episode: 158, steps: 11
# episode: 159, steps: 12
# episode: 160, steps: 12
# episode: 161, steps: 14
# episode: 162, steps: 10
# episode: 163, steps: 18
# episode: 164, steps: 17
# episode: 165, steps: 19
# episode: 166, steps: 11
# episode: 167, steps: 23
# episode: 168, steps: 16
# episode: 169, steps: 18
# episode: 170, steps: 12
# episode: 171, steps: 50
# episode: 172, steps: 13
# episode: 173, steps: 24
# episode: 174, steps: 22
# episode: 175, steps: 57
# episode: 176, steps: 13
# episode: 177, steps: 13
# episode: 178, steps: 9
# episode: 179, steps: 12
# episode: 180, steps: 17
# episode: 181, steps: 53
# episode: 182, steps: 38
# episode: 183, steps: 19
# episode: 184, steps: 17
# episode: 185, steps: 20
# episode: 186, steps: 22
# episode: 187, steps: 16
# episode: 188, steps: 22
# episode: 189, steps: 24
# episode: 190, steps: 17
# episode: 191, steps: 12
# episode: 192, steps: 23
# episode: 193, steps: 10
# episode: 194, steps: 30
# episode: 195, steps: 15
# episode: 196, steps: 12
# episode: 197, steps: 18
# episode: 198, steps: 18
# episode: 199, steps: 25
# episode: 200, steps: 36
# episode: 201, steps: 67
# episode: 202, steps: 20
# episode: 203, steps: 12
# episode: 204, steps: 38
# episode: 205, steps: 39
# episode: 206, steps: 17
# episode: 207, steps: 43
# episode: 208, steps: 30
# episode: 209, steps: 24
# episode: 210, steps: 24
# episode: 211, steps: 39
# episode: 212, steps: 65
# episode: 213, steps: 13
# episode: 214, steps: 18
# episode: 215, steps: 12
# episode: 216, steps: 14
# episode: 217, steps: 9
# episode: 218, steps: 34
# episode: 219, steps: 23
# episode: 220, steps: 26
# episode: 221, steps: 23
# episode: 222, steps: 31
# episode: 223, steps: 12
# episode: 224, steps: 23
# episode: 225, steps: 39
# episode: 226, steps: 96
# episode: 227, steps: 59
# episode: 228, steps: 30
# episode: 229, steps: 18
# episode: 230, steps: 18
# episode: 231, steps: 12
# episode: 232, steps: 24
# episode: 233, steps: 17
# episode: 234, steps: 21
# episode: 235, steps: 38
# episode: 236, steps: 12
# episode: 237, steps: 23
# episode: 238, steps: 20
# episode: 239, steps: 16
# episode: 240, steps: 9
# episode: 241, steps: 18
# episode: 242, steps: 12
# episode: 243, steps: 18
# episode: 244, steps: 19
# episode: 245, steps: 32
# episode: 246, steps: 49
# episode: 247, steps: 17
# episode: 248, steps: 14
# episode: 249, steps: 8
# episode: 250, steps: 13
# episode: 251, steps: 19
# episode: 252, steps: 17
# episode: 253, steps: 19
# episode: 254, steps: 17
# episode: 255, steps: 15
# episode: 256, steps: 25
# episode: 257, steps: 15
# episode: 258, steps: 15
# episode: 259, steps: 12
# episode: 260, steps: 12
# episode: 261, steps: 26
# episode: 262, steps: 39
# episode: 263, steps: 12
# episode: 264, steps: 9
# episode: 265, steps: 18
# episode: 266, steps: 41
# episode: 267, steps: 17
# episode: 268, steps: 8
# episode: 269, steps: 48
# episode: 270, steps: 36
# episode: 271, steps: 37
# episode: 272, steps: 20
# episode: 273, steps: 22
# episode: 274, steps: 41
# episode: 275, steps: 19
# episode: 276, steps: 15
# episode: 277, steps: 75
# episode: 278, steps: 29
# episode: 279, steps: 11
# episode: 280, steps: 23
# episode: 281, steps: 36
# episode: 282, steps: 13
# episode: 283, steps: 10
# episode: 284, steps: 11
# episode: 285, steps: 17
# episode: 286, steps: 52
# episode: 287, steps: 12
# episode: 288, steps: 27
# episode: 289, steps: 18
# episode: 290, steps: 64
# episode: 291, steps: 10
# episode: 292, steps: 15
# episode: 293, steps: 19
# episode: 294, steps: 12
# episode: 295, steps: 8
# episode: 296, steps: 19
# episode: 297, steps: 13
# episode: 298, steps: 11
# episode: 299, steps: 27
# episode: 300, steps: 10
# episode: 301, steps: 21
# episode: 302, steps: 10
# episode: 303, steps: 46
# episode: 304, steps: 31
# episode: 305, steps: 11
# episode: 306, steps: 50
# episode: 307, steps: 14
# episode: 308, steps: 39
# episode: 309, steps: 15
# episode: 310, steps: 22
# episode: 311, steps: 15
# episode: 312, steps: 19
# episode: 313, steps: 33
# episode: 314, steps: 13
# episode: 315, steps: 33
# episode: 316, steps: 10
# episode: 317, steps: 19
# episode: 318, steps: 11
# episode: 319, steps: 14
# episode: 320, steps: 14
# episode: 321, steps: 11
# episode: 322, steps: 17
# episode: 323, steps: 9
# episode: 324, steps: 20
# episode: 325, steps: 19
# episode: 326, steps: 13
# episode: 327, steps: 17
# episode: 328, steps: 12
# episode: 329, steps: 29
# episode: 330, steps: 12
# episode: 331, steps: 25
# episode: 332, steps: 10
# episode: 333, steps: 34
# episode: 334, steps: 11
# episode: 335, steps: 14
# episode: 336, steps: 26
# episode: 337, steps: 11
# episode: 338, steps: 31
# episode: 339, steps: 28
# episode: 340, steps: 13
# episode: 341, steps: 19
# episode: 342, steps: 10
# episode: 343, steps: 12
# episode: 344, steps: 26
# episode: 345, steps: 26
# episode: 346, steps: 19
# episode: 347, steps: 10
# episode: 348, steps: 11
# episode: 349, steps: 12
# episode: 350, steps: 10
# episode: 351, steps: 15
# episode: 352, steps: 14
# episode: 353, steps: 12
# episode: 354, steps: 15
# episode: 355, steps: 50
# episode: 356, steps: 16
# episode: 357, steps: 13
# episode: 358, steps: 10
# episode: 359, steps: 39
# episode: 360, steps: 30
# episode: 361, steps: 13
# episode: 362, steps: 42
# episode: 363, steps: 11
# episode: 364, steps: 17
# episode: 365, steps: 19
# episode: 366, steps: 9
# episode: 367, steps: 11
# episode: 368, steps: 21
# episode: 369, steps: 38
# episode: 370, steps: 16
# episode: 371, steps: 32
# episode: 372, steps: 20
# episode: 373, steps: 14
# episode: 374, steps: 12
# episode: 375, steps: 16
# episode: 376, steps: 18
# episode: 377, steps: 70
# episode: 378, steps: 13
# episode: 379, steps: 20
# episode: 380, steps: 15
# episode: 381, steps: 12
# episode: 382, steps: 14
# episode: 383, steps: 14
# episode: 384, steps: 11
# episode: 385, steps: 8
# episode: 386, steps: 33
# episode: 387, steps: 23
# episode: 388, steps: 22
# episode: 389, steps: 49
# episode: 390, steps: 11
# episode: 391, steps: 20
# episode: 392, steps: 9
# episode: 393, steps: 38
# episode: 394, steps: 56
# episode: 395, steps: 11
# episode: 396, steps: 16
# episode: 397, steps: 14
# episode: 398, steps: 16
# episode: 399, steps: 35
# episode: 400, steps: 22
# episode: 401, steps: 16
# episode: 402, steps: 12
# episode: 403, steps: 39
# episode: 404, steps: 18
# episode: 405, steps: 20
# episode: 406, steps: 14
# episode: 407, steps: 90
# episode: 408, steps: 33
# episode: 409, steps: 37
# episode: 410, steps: 30
# episode: 411, steps: 25
# episode: 412, steps: 17
# episode: 413, steps: 18
# episode: 414, steps: 13
# episode: 415, steps: 11
# episode: 416, steps: 37
# episode: 417, steps: 17
# episode: 418, steps: 16
# episode: 419, steps: 53
# episode: 420, steps: 34
# episode: 421, steps: 14
# episode: 422, steps: 16
# episode: 423, steps: 21
# episode: 424, steps: 14
# episode: 425, steps: 13
# episode: 426, steps: 14
# episode: 427, steps: 8
# episode: 428, steps: 10
# episode: 429, steps: 20
# episode: 430, steps: 14
# episode: 431, steps: 27
# episode: 432, steps: 14
# episode: 433, steps: 13
# episode: 434, steps: 14
# episode: 435, steps: 27
# episode: 436, steps: 20
# episode: 437, steps: 17
# episode: 438, steps: 11
# episode: 439, steps: 24
# episode: 440, steps: 29
# episode: 441, steps: 11
# episode: 442, steps: 13
# episode: 443, steps: 37
# episode: 444, steps: 22
# episode: 445, steps: 18
# episode: 446, steps: 20
# episode: 447, steps: 36
# episode: 448, steps: 16
# episode: 449, steps: 18
# episode: 450, steps: 16
# episode: 451, steps: 23
# episode: 452, steps: 16
# episode: 453, steps: 11
# episode: 454, steps: 12
# episode: 455, steps: 29
# episode: 456, steps: 14
# episode: 457, steps: 10
# episode: 458, steps: 32
# episode: 459, steps: 49
# episode: 460, steps: 9
# episode: 461, steps: 16
# episode: 462, steps: 36
# episode: 463, steps: 35
# episode: 464, steps: 31
# episode: 465, steps: 28
# episode: 466, steps: 9
# episode: 467, steps: 20
# episode: 468, steps: 20
# episode: 469, steps: 16
# episode: 470, steps: 19
# episode: 471, steps: 12
# episode: 472, steps: 28
# episode: 473, steps: 10
# episode: 474, steps: 17
# episode: 475, steps: 24
# episode: 476, steps: 29
# episode: 477, steps: 23
# episode: 478, steps: 13
# episode: 479, steps: 8
# episode: 480, steps: 27
# episode: 481, steps: 17
# episode: 482, steps: 15
# episode: 483, steps: 11
# episode: 484, steps: 11
# episode: 485, steps: 11
# episode: 486, steps: 10
# episode: 487, steps: 13
# episode: 488, steps: 11
# episode: 489, steps: 13
# episode: 490, steps: 44
# episode: 491, steps: 39
# episode: 492, steps: 27
# episode: 493, steps: 17
# episode: 494, steps: 14
# episode: 495, steps: 12
# episode: 496, steps: 12
# episode: 497, steps: 22
# episode: 498, steps: 10
# episode: 499, steps: 29
